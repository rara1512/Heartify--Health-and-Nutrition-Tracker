# %% [markdown]
# ## Introduction
#
# This is a binary classification algorithm used to figure out if a patient has heart disease. In this example, we will upload sample data from Cleveland Heart Disease dataset taken from the UCI repository (Kaggle).  The dataset consists of 1025 individuals data.  Please see data repository for column description and sample data.

# %%
bucket = 'sagemaker-heartify'
prefix = 'sagemaker/heart'

data_key = 'heart.csv'
data_location = 's3://{}/{}'.format(bucket, data_key)
 
import boto3
import re
from sagemaker import get_execution_role

role = get_execution_role()

# %% [markdown]
# ### Data ingestion

# %%
import pandas as pd
import json

heart_data = pd.read_csv(data_location)
heart_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
heart_data.count()
# Out:
# age         1025
# sex         1025
# cp          1025
# trestbps    1025
# chol        1025
# fbs         1025
# restecg     1025
# thalach     1025
# exang       1025
# oldpeak     1025
# slope       1025
# ca          1025
# thal        1025
# target      1025
# dtype: int64

# %% [markdown]
# ### Data conversion
#
# The Linear Learner algorithms expects a features matrix and labels vector.

# %%
import numpy as np
vectors = np.array(heart_data).astype('float32')

labels = vectors[:,13]
print ("label data is")
print (labels)
training_data = vectors[:, :13]
print ("Training data is")
print (training_data)
# Out:
# label data is
# [0. 0. 0. ... 0. 1. 0.]
# Training data is
# [[52.  1.  0. ...  2.  2.  3.]
#  [53.  1.  0. ...  0.  0.  3.]
#  [70.  1.  0. ...  0.  0.  3.]
#  ...
#  [47.  1.  0. ...  1.  1.  2.]
#  [50.  0.  0. ...  2.  0.  2.]
#  [54.  1.  0. ...  1.  1.  3.]]

# %%
import io
import os
import sagemaker.amazon.common as smac

buf = io.BytesIO()
smac.write_numpy_to_dense_tensor(buf, training_data, labels)
buf.seek(0)

key = 'recordio-pb-data'
boto3.resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train', key)).upload_fileobj(buf)
s3_train_data = 's3://{}/{}/train/{}'.format(bucket, prefix, key)
print('uploaded training data location: {}'.format(s3_train_data))
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/boto3/compat.py:88: PythonDeprecationWarning: Boto3 will no longer support Python 3.6 starting May 30, 2022. To continue receiving service updates, bug fixes, and security updates please upgrade to Python 3.7 or later. More information can be found here: https://aws.amazon.com/blogs/developer/python-support-policy-updates-for-aws-sdks-and-tools/
#   warnings.warn(warning, PythonDeprecationWarning)
# uploaded training data location: s3://sagemaker-heartify/sagemaker/heart/train/recordio-pb-data

# %%
output_location = 's3://{}/{}/output'.format(bucket, prefix)
print('training artifacts will be uploaded to: {}'.format(output_location))
# Out:
# training artifacts will be uploaded to: s3://sagemaker-heartify/sagemaker/heart/output

# %% [markdown]
# ## Training the linear model

# %% [markdown]
# We will do a binary classification (patient either has heart disease or not), train the model on the specified compute (e.g. ml.m4.xlarge), and we will sepcify the features or dimiensions in our training set.

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri
import sagemaker

container = get_image_uri(boto3.Session().region_name, 'linear-learner', "latest")

sess = sagemaker.Session()
linear = sagemaker.estimator.Estimator(container,
                                       role, 
                                       train_instance_count=1, 
                                       train_instance_type='ml.m4.xlarge',
                                       output_path=output_location,
                                       sagemaker_session=sess)
linear.set_hyperparameters(feature_dim=13,
                           predictor_type='binary_classifier',
                           mini_batch_size=100)

linear.fit({'train': s3_train_data})
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: latest.
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# 2022-05-15 19:19:20 Starting - Starting the training job...
# 2022-05-15 19:19:46 Starting - Preparing the instances for trainingProfilerReport-1652642360: InProgress
# .........
# 2022-05-15 19:21:08 Downloading - Downloading input data...
# 2022-05-15 19:21:45 Training - Downloading the training image.....Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [05/15/2022 19:22:36 INFO 139914211612480] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [05/15/2022 19:22:36 INFO 139914211612480] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '13', 'mini_batch_size': '100', 'predictor_type': 'binary_classifier'}
# [05/15/2022 19:22:36 INFO 139914211612480] Final configuration: {'mini_batch_size': '100', 'epochs': '15', 'feature_dim': '13', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [05/15/2022 19:22:36 WARNING 139914211612480] Loggers have already been setup.
# Process 1 is a worker.
# [05/15/2022 19:22:36 INFO 139914211612480] Using default worker.
#
# 2022-05-15 19:22:50 Uploading - Uploading generated training model[05/15/2022 19:22:36 INFO 139914211612480] Checkpoint loading and saving are disabled.
# [2022-05-15 19:22:37.013] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 25, "num_examples": 1, "num_bytes": 9600}
# [05/15/2022 19:22:37 INFO 139914211612480] Create Store: local
# [2022-05-15 19:22:37.086] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 71, "num_examples": 11, "num_bytes": 98400}
# [05/15/2022 19:22:37 INFO 139914211612480] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f3ff0325190>
# [05/15/2022 19:22:37 INFO 139914211612480] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [ 9.096696    0.46166652  1.0293202  17.56585    51.68505     0.35707137
#   0.52461034 23.01645     0.4726849   1.1757326   0.61688256  1.0305296
#   0.6202185 ]
# <NDArray 13 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [5.4488998e+01 6.9200003e-01 9.5000005e-01 1.3178101e+02 2.4618500e+02
#  1.5000001e-01 5.2800000e-01 1.4908899e+02 3.3699995e-01 1.0721999e+00
#  1.3839999e+00 7.5299996e-01 2.3230000e+00]
# <NDArray 13 @cpu(0)>}
# [05/15/2022 19:22:37 INFO 139914211612480] nvidia-smi: took 0.032 seconds to run.
# [05/15/2022 19:22:37 INFO 139914211612480] nvidia-smi identified 0 GPUs.
# [05/15/2022 19:22:37 INFO 139914211612480] Number of GPUs being used: 0
# #metrics {"StartTime": 1652642557.2192686, "EndTime": 1652642557.21931, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 1125.0, "count": 1, "min": 1125, "max": 1125}, "Total Batches Seen": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Max Records Seen Between Resets": {"sum": 1025.0, "count": 1, "min": 1025, "max": 1025}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2022-05-15 19:22:37.679] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 459, "num_examples": 11, "num_bytes": 98400}
# #metrics {"StartTime": 1652642557.6796367, "EndTime": 1652642557.6797647, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6448936882019043, "count": 1, "min": 0.6448936882019043, "max": 0.6448936882019043}}}
# #metrics {"StartTime": 1652642557.679888, "EndTime": 1652642557.679912, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6703454246520996, "count": 1, "min": 0.6703454246520996, "max": 0.6703454246520996}}}
# #metrics {"StartTime": 1652642557.6799881, "EndTime": 1652642557.680011, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6829539871215821, "count": 1, "min": 0.6829539871215821, "max": 0.6829539871215821}}}
# #metrics {"StartTime": 1652642557.6800916, "EndTime": 1652642557.6801136, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6896181945800781, "count": 1, "min": 0.6896181945800781, "max": 0.6896181945800781}}}
# #metrics {"StartTime": 1652642557.680184, "EndTime": 1652642557.6802025, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5061203308105469, "count": 1, "min": 0.5061203308105469, "max": 0.5061203308105469}}}
# #metrics {"StartTime": 1652642557.6802647, "EndTime": 1652642557.68028, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5120074348449707, "count": 1, "min": 0.5120074348449707, "max": 0.5120074348449707}}}
# #metrics {"StartTime": 1652642557.6803317, "EndTime": 1652642557.680348, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5251781997680665, "count": 1, "min": 0.5251781997680665, "max": 0.5251781997680665}}}
# #metrics {"StartTime": 1652642557.6803992, "EndTime": 1652642557.6804135, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5213347053527833, "count": 1, "min": 0.5213347053527833, "max": 0.5213347053527833}}}
# #metrics {"StartTime": 1652642557.6804676, "EndTime": 1652642557.680482, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7096354598999024, "count": 1, "min": 0.7096354598999024, "max": 0.7096354598999024}}}
# #metrics {"StartTime": 1652642557.6805136, "EndTime": 1652642557.6805217, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6839994125366211, "count": 1, "min": 0.6839994125366211, "max": 0.6839994125366211}}}
# #metrics {"StartTime": 1652642557.6805475, "EndTime": 1652642557.680555, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6827139053344726, "count": 1, "min": 0.6827139053344726, "max": 0.6827139053344726}}}
# #metrics {"StartTime": 1652642557.680596, "EndTime": 1652642557.6806097, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7074527740478516, "count": 1, "min": 0.7074527740478516, "max": 0.7074527740478516}}}
# #metrics {"StartTime": 1652642557.6806397, "EndTime": 1652642557.6806479, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5152697944641114, "count": 1, "min": 0.5152697944641114, "max": 0.5152697944641114}}}
# #metrics {"StartTime": 1652642557.680674, "EndTime": 1652642557.6806815, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5046029510498047, "count": 1, "min": 0.5046029510498047, "max": 0.5046029510498047}}}
# #metrics {"StartTime": 1652642557.6807065, "EndTime": 1652642557.6807137, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5238471565246582, "count": 1, "min": 0.5238471565246582, "max": 0.5238471565246582}}}
# #metrics {"StartTime": 1652642557.6807392, "EndTime": 1652642557.680752, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5221756782531738, "count": 1, "min": 0.5221756782531738, "max": 0.5221756782531738}}}
# #metrics {"StartTime": 1652642557.6807976, "EndTime": 1652642557.6808088, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6651507110595704, "count": 1, "min": 0.6651507110595704, "max": 0.6651507110595704}}}
# #metrics {"StartTime": 1652642557.680859, "EndTime": 1652642557.6808763, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6872627563476562, "count": 1, "min": 0.6872627563476562, "max": 0.6872627563476562}}}
# #metrics {"StartTime": 1652642557.6809282, "EndTime": 1652642557.6809494, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6263764953613281, "count": 1, "min": 0.6263764953613281, "max": 0.6263764953613281}}}
# #metrics {"StartTime": 1652642557.6809993, "EndTime": 1652642557.6810155, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.643755386352539, "count": 1, "min": 0.643755386352539, "max": 0.643755386352539}}}
# #metrics {"StartTime": 1652642557.6810656, "EndTime": 1652642557.6810868, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5812713775634766, "count": 1, "min": 0.5812713775634766, "max": 0.5812713775634766}}}
# #metrics {"StartTime": 1652642557.6811383, "EndTime": 1652642557.6811547, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.579275405883789, "count": 1, "min": 0.579275405883789, "max": 0.579275405883789}}}
# #metrics {"StartTime": 1652642557.6812086, "EndTime": 1652642557.681226, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5785232620239258, "count": 1, "min": 0.5785232620239258, "max": 0.5785232620239258}}}
# #metrics {"StartTime": 1652642557.6812813, "EndTime": 1652642557.6812985, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.571240650177002, "count": 1, "min": 0.571240650177002, "max": 0.571240650177002}}}
# #metrics {"StartTime": 1652642557.6813529, "EndTime": 1652642557.681371, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6913818969726563, "count": 1, "min": 0.6913818969726563, "max": 0.6913818969726563}}}
# #metrics {"StartTime": 1652642557.6814272, "EndTime": 1652642557.681443, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.683146614074707, "count": 1, "min": 0.683146614074707, "max": 0.683146614074707}}}
# #metrics {"StartTime": 1652642557.6814926, "EndTime": 1652642557.681508, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6771091461181641, "count": 1, "min": 0.6771091461181641, "max": 0.6771091461181641}}}
# #metrics {"StartTime": 1652642557.6815586, "EndTime": 1652642557.6815739, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6976011123657226, "count": 1, "min": 0.6976011123657226, "max": 0.6976011123657226}}}
# #metrics {"StartTime": 1652642557.681626, "EndTime": 1652642557.6816416, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7461448135375977, "count": 1, "min": 0.7461448135375977, "max": 0.7461448135375977}}}
# #metrics {"StartTime": 1652642557.6816947, "EndTime": 1652642557.6817105, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7478668441772461, "count": 1, "min": 0.7478668441772461, "max": 0.7478668441772461}}}
# #metrics {"StartTime": 1652642557.6817632, "EndTime": 1652642557.6817799, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7468720397949219, "count": 1, "min": 0.7468720397949219, "max": 0.7468720397949219}}}
# #metrics {"StartTime": 1652642557.6818345, "EndTime": 1652642557.6818523, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7399884185791016, "count": 1, "min": 0.7399884185791016, "max": 0.7399884185791016}}}
# [05/15/2022 19:22:37 INFO 139914211612480] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.6448936882019043
# [05/15/2022 19:22:37 INFO 139914211612480] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.5046029510498047
# [05/15/2022 19:22:37 INFO 139914211612480] Epoch 0: Loss improved. Updating best model
# [05/15/2022 19:22:37 INFO 139914211612480] Saving model for epoch: 0
# [05/15/2022 19:22:37 INFO 139914211612480] Saved checkpoint to "/tmp/tmp744qbd97/mx-mod-0000.params"
# [05/15/2022 19:22:37 INFO 139914211612480] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1652642557.219643, "EndTime": 1652642557.699014, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 2150.0, "count": 1, "min": 2150, "max": 2150}, "Total Batches Seen": {"sum": 23.0, "count": 1, "min": 23, "max": 23}, "Max Records Seen Between Resets": {"sum": 1025.0, "count": 1, "min": 1025, "max": 1025}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 1025.0, "count": 1, "min": 1025, "max": 1025}, "Number of Batches Since Last Reset": {"sum": 11.0, "count": 1, "min": 11, "max": 11}}}
# [05/15/2022 19:22:37 INFO 139914211612480] #throughput_metric: host=algo-1, train throughput=2137.4730837172833 records/second
# [2022-05-15 19:22:38.127] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 6, "duration": 428, "num_examples": 11, "num_bytes": 98400}
# #metrics {"StartTime": 1652642558.1278718, "EndTime": 1652642558.1281796, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5742647132873535, "count": 1, "min": 0.5742647132873535, "max": 0.5742647132873535}}}
# #metrics {"StartTime": 1652642558.1282675, "EndTime": 1652642558.1282895, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5963917999267578, "count": 1, "min": 0.5963917999267578, "max": 0.5963917999267578}}}
# #metrics {"StartTime": 1652642558.1283503, "EndTime": 1652642558.128368, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6047219581604004, "count": 1, "min": 0.6047219581604004, "max": 0.6047219581604004}}}
# #metrics {"StartTime": 1652642558.1284275, "EndTime": 1652642558.1284459, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6128908195495606, "count": 1, "min": 0.6128908195495606, "max": 0.6128908195495606}}}
# #metrics {"StartTime": 1652642558.128504, "EndTime": 1652642558.1285224, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.39430338287353517, "count": 1, "min": 0.39430338287353517, "max": 0.39430338287353517}}}
# #metrics {"StartTime": 1652642558.1285796, "EndTime": 1652642558.128597, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.39710559844970705, "count": 1, "min": 0.39710559844970705, "max": 0.39710559844970705}}}
# #metrics {"StartTime": 1652642558.1286528, "EndTime": 1652642558.128669, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3974785499572754, "count": 1, "min": 0.3974785499572754, "max": 0.3974785499572754}}}
# #metrics {"StartTime": 1652642558.1287243, "EndTime": 1652642558.1287425, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.39875835609436033, "count": 1, "min": 0.39875835609436033, "max": 0.39875835609436033}}}
# #metrics {"StartTime": 1652642558.1287992, "EndTime": 1652642558.1288154, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6291814193725586, "count": 1, "min": 0.6291814193725586, "max": 0.6291814193725586}}}
# #metrics {"StartTime": 1652642558.1288698, "EndTime": 1652642558.1288877, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6072086563110352, "count": 1, "min": 0.6072086563110352, "max": 0.6072086563110352}}}
# #metrics {"StartTime": 1652642558.1289434, "EndTime": 1652642558.1289608, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.607553882598877, "count": 1, "min": 0.607553882598877, "max": 0.607553882598877}}}
# #metrics {"StartTime": 1652642558.129014, "EndTime": 1652642558.129032, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6267080307006836, "count": 1, "min": 0.6267080307006836, "max": 0.6267080307006836}}}
# #metrics {"StartTime": 1652642558.1290872, "EndTime": 1652642558.1291044, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.38901749229431154, "count": 1, "min": 0.38901749229431154, "max": 0.38901749229431154}}}
# #metrics {"StartTime": 1652642558.1291611, "EndTime": 1652642558.1291785, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3860333995819092, "count": 1, "min": 0.3860333995819092, "max": 0.3860333995819092}}}
# #metrics {"StartTime": 1652642558.1292326, "EndTime": 1652642558.1292505, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.39006924438476565, "count": 1, "min": 0.39006924438476565, "max": 0.39006924438476565}}}
# #metrics {"StartTime": 1652642558.1293054, "EndTime": 1652642558.1293228, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3921948947906494, "count": 1, "min": 0.3921948947906494, "max": 0.3921948947906494}}}
# #metrics {"StartTime": 1652642558.1293778, "EndTime": 1652642558.1293948, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5989276237487793, "count": 1, "min": 0.5989276237487793, "max": 0.5989276237487793}}}
# #metrics {"StartTime": 1652642558.1294575, "EndTime": 1652642558.1294746, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6130903663635254, "count": 1, "min": 0.6130903663635254, "max": 0.6130903663635254}}}
# #metrics {"StartTime": 1652642558.129528, "EndTime": 1652642558.1295447, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5699026527404785, "count": 1, "min": 0.5699026527404785, "max": 0.5699026527404785}}}
# #metrics {"StartTime": 1652642558.1295972, "EndTime": 1652642558.1296139, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5855988807678223, "count": 1, "min": 0.5855988807678223, "max": 0.5855988807678223}}}
# #metrics {"StartTime": 1652642558.1296666, "EndTime": 1652642558.1296837, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5673557624816895, "count": 1, "min": 0.5673557624816895, "max": 0.5673557624816895}}}
# #metrics {"StartTime": 1652642558.1297362, "EndTime": 1652642558.1297526, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5810415420532227, "count": 1, "min": 0.5810415420532227, "max": 0.5810415420532227}}}
# #metrics {"StartTime": 1652642558.1298048, "EndTime": 1652642558.1298215, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5818798141479492, "count": 1, "min": 0.5818798141479492, "max": 0.5818798141479492}}}
# #metrics {"StartTime": 1652642558.1298735, "EndTime": 1652642558.1298895, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5950642204284669, "count": 1, "min": 0.5950642204284669, "max": 0.5950642204284669}}}
# #metrics {"StartTime": 1652642558.1299431, "EndTime": 1652642558.1299593, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6895414581298828, "count": 1, "min": 0.6895414581298828, "max": 0.6895414581298828}}}
# #metrics {"StartTime": 1652642558.1300128, "EndTime": 1652642558.1300282, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6918047103881836, "count": 1, "min": 0.6918047103881836, "max": 0.6918047103881836}}}
# #metrics {"StartTime": 1652642558.1300805, "EndTime": 1652642558.1300983, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6946286697387696, "count": 1, "min": 0.6946286697387696, "max": 0.6946286697387696}}}
# #metrics {"StartTime": 1652642558.1301517, "EndTime": 1652642558.130168, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6833170471191407, "count": 1, "min": 0.6833170471191407, "max": 0.6833170471191407}}}
# #metrics {"StartTime": 1652642558.1302233, "EndTime": 1652642558.13024, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7362608261108399, "count": 1, "min": 0.7362608261108399, "max": 0.7362608261108399}}}
# #metrics {"StartTime": 1652642558.1302924, "EndTime": 1652642558.1303082, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7331953201293945, "count": 1, "min": 0.7331953201293945, "max": 0.7331953201293945}}}
# #metrics {"StartTime": 1652642558.1303632, "EndTime": 1652642558.1303792, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7330330657958984, "count": 1, "min": 0.7330330657958984, "max": 0.7330330657958984}}}
# #metrics {"StartTime": 1652642558.1304383, "EndTime": 1652642558.1304553, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7314142990112305, "count": 1, "min": 0.7314142990112305, "max": 0.7314142990112305}}}
# [05/15/2022 19:22:38 INFO 139914211612480] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.5742647132873535
# [05/15/2022 19:22:38 INFO 139914211612480] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.3860333995819092
# [05/15/2022 19:22:38 INFO 139914211612480] Epoch 1: Loss improved. Updating best model
# [05/15/2022 19:22:38 INFO 139914211612480] Saving model for epoch: 1
# [05/15/2022 19:22:38 INFO 139914211612480] Saved checkpoint to "/tmp/tmppbpzseta/mx-mod-0000.params"
# [05/15/2022 19:22:38 INFO 139914211612480] #progress_metric: host=algo-1, completed 13.333333333333334 % of epochs
# #metrics {"StartTime": 1652642557.6994057, "EndTime": 1652642558.1403995, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 3175.0, "count": 1, "min": 3175, "max": 3175}, "Total Batches Seen": {"sum": 34.0, "count": 1, "min": 34, "max": 34}, "Max Records Seen Between Resets": {"sum": 1025.0, "count": 1, "min": 1025, "max": 1025}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 1025.0, "count": 1, "min": 1025, "max": 1025}, "Number of Batches Since Last Reset": {"sum": 11.0, "count": 1, "min": 11, "max": 11}}}
# [05/15/2022 19:22:38 INFO 139914211612480] #throughput_metric: host=algo-1, train throughput=2323.3989200032856 records/second
# [2022-05-15 19:22:38.562] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 8, "duration": 421, "num_examples": 11, "num_bytes": 98400}
# #metrics {"StartTime": 1652642558.562999, "EndTime": 1652642558.5630918, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5229445266723632, "count": 1, "min": 0.5229445266723632, "max": 0.5229445266723632}}}
# #metrics {"StartTime": 1652642558.5631769, "EndTime": 1652642558.5631986, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5414283714294433, "count": 1, "min": 0.5414283714294433, "max": 0.5414283714294433}}}
# #metrics {"StartTime": 1652642558.5632606, "EndTime": 1652642558.5632792, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5466588249206543, "count": 1, "min": 0.5466588249206543, "max": 0.5466588249206543}}}
# #metrics {"StartTime": 1652642558.5633404, "EndTime": 1652642558.5633593, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5553667259216308, "count": 1, "min": 0.5553667259216308, "max": 0.5553667259216308}}}
# #metrics {"StartTime": 1652642558.5634198, "EndTime": 1652642558.5634394, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.36797806549072265, "count": 1, "min": 0.36797806549072265, "max": 0.36797806549072265}}}
# #metrics {"StartTime": 1652642558.5634975, "EndTime": 1652642558.5635157, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3710129985809326, "count": 1, "min": 0.3710129985809326, "max": 0.3710129985809326}}}
# #metrics {"StartTime": 1652642558.5635705, "EndTime": 1652642558.5635943, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.37221785545349123, "count": 1, "min": 0.37221785545349123, "max": 0.37221785545349123}}}
# #metrics {"StartTime": 1652642558.5636516, "EndTime": 1652642558.5636685, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3714898738861084, "count": 1, "min": 0.3714898738861084, "max": 0.3714898738861084}}}
# #metrics {"StartTime": 1652642558.5637236, "EndTime": 1652642558.5637417, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5685745506286621, "count": 1, "min": 0.5685745506286621, "max": 0.5685745506286621}}}
# #metrics {"StartTime": 1652642558.5637965, "EndTime": 1652642558.5638146, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5493344306945801, "count": 1, "min": 0.5493344306945801, "max": 0.5493344306945801}}}
# #metrics {"StartTime": 1652642558.5638742, "EndTime": 1652642558.563893, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5517316436767579, "count": 1, "min": 0.5517316436767579, "max": 0.5517316436767579}}}
# #metrics {"StartTime": 1652642558.5639615, "EndTime": 1652642558.56398, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5656144142150878, "count": 1, "min": 0.5656144142150878, "max": 0.5656144142150878}}}
# #metrics {"StartTime": 1652642558.5640392, "EndTime": 1652642558.5640566, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3606506633758545, "count": 1, "min": 0.3606506633758545, "max": 0.3606506633758545}}}
# #metrics {"StartTime": 1652642558.5641236, "EndTime": 1652642558.564143, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3591932430267334, "count": 1, "min": 0.3591932430267334, "max": 0.3591932430267334}}}
# #metrics {"StartTime": 1652642558.564208, "EndTime": 1652642558.564227, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3610041027069092, "count": 1, "min": 0.3610041027069092, "max": 0.3610041027069092}}}
# #metrics {"StartTime": 1652642558.5642922, "EndTime": 1652642558.5643115, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3609672756195068, "count": 1, "min": 0.3609672756195068, "max": 0.3609672756195068}}}
# #metrics {"StartTime": 1652642558.564374, "EndTime": 1652642558.564393, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5578905982971192, "count": 1, "min": 0.5578905982971192, "max": 0.5578905982971192}}}
# #metrics {"StartTime": 1652642558.5644503, "EndTime": 1652642558.564468, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5649095039367675, "count": 1, "min": 0.5649095039367675, "max": 0.5649095039367675}}}
# #metrics {"StartTime": 1652642558.5645351, "EndTime": 1652642558.5645545, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5384728240966797, "count": 1, "min": 0.5384728240966797, "max": 0.5384728240966797}}}
# #metrics {"StartTime": 1652642558.564612, "EndTime": 1652642558.5646307, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5503272438049316, "count": 1, "min": 0.5503272438049316, "max": 0.5503272438049316}}}
# #metrics {"StartTime": 1652642558.5646887, "EndTime": 1652642558.5647073, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5505285720825195, "count": 1, "min": 0.5505285720825195, "max": 0.5505285720825195}}}
# #metrics {"StartTime": 1652642558.5647666, "EndTime": 1652642558.564785, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.547309326171875, "count": 1, "min": 0.547309326171875, "max": 0.547309326171875}}}
# #metrics {"StartTime": 1652642558.5648417, "EndTime": 1652642558.5648572, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5447442359924316, "count": 1, "min": 0.5447442359924316, "max": 0.5447442359924316}}}
# #metrics {"StartTime": 1652642558.5649102, "EndTime": 1652642558.5649264, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5380281410217285, "count": 1, "min": 0.5380281410217285, "max": 0.5380281410217285}}}
# #metrics {"StartTime": 1652642558.5649948, "EndTime": 1652642558.5650132, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.689502311706543, "count": 1, "min": 0.689502311706543, "max": 0.689502311706543}}}
# #metrics {"StartTime": 1652642558.565075, "EndTime": 1652642558.5650935, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6904029312133789, "count": 1, "min": 0.6904029312133789, "max": 0.6904029312133789}}}
# #metrics {"StartTime": 1652642558.565154, "EndTime": 1652642558.565171, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6925729064941406, "count": 1, "min": 0.6925729064941406, "max": 0.6925729064941406}}}
# #metrics {"StartTime": 1652642558.565224, "EndTime": 1652642558.5652392, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6920470809936523, "count": 1, "min": 0.6920470809936523, "max": 0.6920470809936523}}}
# #metrics {"StartTime": 1652642558.5652907, "EndTime": 1652642558.5653064, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6993769912719726, "count": 1, "min": 0.6993769912719726, "max": 0.6993769912719726}}}
# #metrics {"StartTime": 1652642558.5653605, "EndTime": 1652642558.5653772, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6991228256225586, "count": 1, "min": 0.6991228256225586, "max": 0.6991228256225586}}}
# #metrics {"StartTime": 1652642558.5654297, "EndTime": 1652642558.565447, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6994604873657226, "count": 1, "min": 0.6994604873657226, "max": 0.6994604873657226}}}
# #metrics {"StartTime": 1652642558.5655098, "EndTime": 1652642558.5655284, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7004498977661133, "count": 1, "min": 0.7004498977661133, "max": 0.7004498977661133}}}
# [05/15/2022 19:22:38 INFO 139914211612480] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.5229445266723632
# [05/15/2022 19:22:38 INFO 139914211612480] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.3591932430267334
# [05/15/2022 19:22:38 INFO 139914211612480] Epoch 2: Loss improved. Updating best model
# [05/15/2022 19:22:38 INFO 139914211612480] Saving model for epoch: 2
# [05/15/2022 19:22:38 INFO 139914211612480] Saved checkpoint to "/tmp/tmpl_1bc3jb/mx-mod-0000.params"
# [05/15/2022 19:22:38 INFO 139914211612480] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1652642558.1407592, "EndTime": 1652642558.5780745, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 4200.0, "count": 1, "min": 4200, "max": 4200}, "Total Batches Seen": {"sum": 45.0, "count": 1, "min": 45, "max": 45}, "Max Records Seen Between Resets": {"sum": 1025.0, "count": 1, "min": 1025, "max": 1025}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 1025.0, "count": 1, "min": 1025, "max": 1025}, "Number of Batches Since Last Reset": {"sum": 11.0, "count": 1, "min": 11, "max": 11}}}
# [05/15/2022 19:22:38 INFO 139914211612480] #throughput_metric: host=algo-1, train throughput=2342.9363043926087 records/second
# [2022-05-15 19:22:39.225] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 10, "duration": 647, "num_examples": 11, "num_bytes": 98400}
# #metrics {"StartTime": 1652642559.2258813, "EndTime": 1652642559.2259886, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4861902236938477, "count": 1, "min": 0.4861902236938477, "max": 0.4861902236938477}}}
# #metrics {"StartTime": 1652642559.2260954, "EndTime": 1652642559.2261164, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5012585067749024, "count": 1, "min": 0.5012585067749024, "max": 0.5012585067749024}}}
# #metrics {"StartTime": 1652642559.2261794, "EndTime": 1652642559.2262, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5043741569519044, "count": 1, "min": 0.5043741569519044, "max": 0.5043741569519044}}}
# #metrics {"StartTime": 1652642559.2262592, "EndTime": 1652642559.2262774, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5129690246582032, "count": 1, "min": 0.5129690246582032, "max": 0.5129690246582032}}}
# #metrics {"StartTime": 1652642559.226335, "EndTime": 1652642559.2263532, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.36624047088623046, "count": 1, "min": 0.36624047088623046, "max": 0.36624047088623046}}}
# #metrics {"StartTime": 1652642559.226413, "EndTime": 1652642559.2264302, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3645413475036621, "count": 1, "min": 0.3645413475036621, "max": 0.3645413475036621}}}
# #metrics {"StartTime": 1652642559.2264857, "EndTime": 1652642559.2265027, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3653440570831299, "count": 1, "min": 0.3653440570831299, "max": 0.3653440570831299}}}
# ...
# #metrics {"StartTime": 1652642561.7338586, "EndTime": 1652642561.7338758, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4147103614807129, "count": 1, "min": 0.4147103614807129, "max": 0.4147103614807129}}}
# #metrics {"StartTime": 1652642561.7340004, "EndTime": 1652642561.734024, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3577041759490967, "count": 1, "min": 0.3577041759490967, "max": 0.3577041759490967}}}
# #metrics {"StartTime": 1652642561.7340875, "EndTime": 1652642561.7341063, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3582565155029297, "count": 1, "min": 0.3582565155029297, "max": 0.3582565155029297}}}
# #metrics {"StartTime": 1652642561.7342207, "EndTime": 1652642561.7342436, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.35743036079406737, "count": 1, "min": 0.35743036079406737, "max": 0.35743036079406737}}}
# #metrics {"StartTime": 1652642561.7343106, "EndTime": 1652642561.734329, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.35838377761840823, "count": 1, "min": 0.35838377761840823, "max": 0.35838377761840823}}}
# #metrics {"StartTime": 1652642561.734455, "EndTime": 1652642561.7344763, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.42122304916381836, "count": 1, "min": 0.42122304916381836, "max": 0.42122304916381836}}}
# #metrics {"StartTime": 1652642561.7346108, "EndTime": 1652642561.7346337, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.40917111206054685, "count": 1, "min": 0.40917111206054685, "max": 0.40917111206054685}}}
# #metrics {"StartTime": 1652642561.7347383, "EndTime": 1652642561.7347522, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4170666275024414, "count": 1, "min": 0.4170666275024414, "max": 0.4170666275024414}}}
# #metrics {"StartTime": 1652642561.7347825, "EndTime": 1652642561.734792, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.416476203918457, "count": 1, "min": 0.416476203918457, "max": 0.416476203918457}}}
# #metrics {"StartTime": 1652642561.7348647, "EndTime": 1652642561.734879, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.35881647109985354, "count": 1, "min": 0.35881647109985354, "max": 0.35881647109985354}}}
# #metrics {"StartTime": 1652642561.734922, "EndTime": 1652642561.7349315, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3595363597869873, "count": 1, "min": 0.3595363597869873, "max": 0.3595363597869873}}}
# #metrics {"StartTime": 1652642561.734958, "EndTime": 1652642561.7349653, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.35888516426086425, "count": 1, "min": 0.35888516426086425, "max": 0.35888516426086425}}}
# #metrics {"StartTime": 1652642561.7350094, "EndTime": 1652642561.7350254, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.3595963649749756, "count": 1, "min": 0.3595963649749756, "max": 0.3595963649749756}}}
# #metrics {"StartTime": 1652642561.7350898, "EndTime": 1652642561.7351074, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5309220428466797, "count": 1, "min": 0.5309220428466797, "max": 0.5309220428466797}}}
# #metrics {"StartTime": 1652642561.7351615, "EndTime": 1652642561.7351782, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.53115869140625, "count": 1, "min": 0.53115869140625, "max": 0.53115869140625}}}
# #metrics {"StartTime": 1652642561.7352316, "EndTime": 1652642561.7352474, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5308672714233399, "count": 1, "min": 0.5308672714233399, "max": 0.5308672714233399}}}
# #metrics {"StartTime": 1652642561.7352974, "EndTime": 1652642561.735313, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5309517211914062, "count": 1, "min": 0.5309517211914062, "max": 0.5309517211914062}}}
# #metrics {"StartTime": 1652642561.7353601, "EndTime": 1652642561.735376, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5394694595336914, "count": 1, "min": 0.5394694595336914, "max": 0.5394694595336914}}}
# #metrics {"StartTime": 1652642561.7354388, "EndTime": 1652642561.7354574, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5409751472473144, "count": 1, "min": 0.5409751472473144, "max": 0.5409751472473144}}}
# #metrics {"StartTime": 1652642561.7355156, "EndTime": 1652642561.7355316, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5393384094238282, "count": 1, "min": 0.5393384094238282, "max": 0.5393384094238282}}}
# #metrics {"StartTime": 1652642561.735585, "EndTime": 1652642561.7356026, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5406265029907227, "count": 1, "min": 0.5406265029907227, "max": 0.5406265029907227}}}
# #metrics {"StartTime": 1652642561.735654, "EndTime": 1652642561.7356696, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6897122192382813, "count": 1, "min": 0.6897122192382813, "max": 0.6897122192382813}}}
# #metrics {"StartTime": 1652642561.7357202, "EndTime": 1652642561.7357368, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6896392211914063, "count": 1, "min": 0.6896392211914063, "max": 0.6896392211914063}}}
# #metrics {"StartTime": 1652642561.7357895, "EndTime": 1652642561.7358057, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6895779037475586, "count": 1, "min": 0.6895779037475586, "max": 0.6895779037475586}}}
# #metrics {"StartTime": 1652642561.7358449, "EndTime": 1652642561.7358537, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6898036270141602, "count": 1, "min": 0.6898036270141602, "max": 0.6898036270141602}}}
# #metrics {"StartTime": 1652642561.7358801, "EndTime": 1652642561.7358932, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6962506408691407, "count": 1, "min": 0.6962506408691407, "max": 0.6962506408691407}}}
# #metrics {"StartTime": 1652642561.7359438, "EndTime": 1652642561.7359595, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6973270568847656, "count": 1, "min": 0.6973270568847656, "max": 0.6973270568847656}}}
# #metrics {"StartTime": 1652642561.7360103, "EndTime": 1652642561.7360268, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6961298904418945, "count": 1, "min": 0.6961298904418945, "max": 0.6961298904418945}}}
# #metrics {"StartTime": 1652642561.7360644, "EndTime": 1652642561.7360737, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6973021621704102, "count": 1, "min": 0.6973021621704102, "max": 0.6973021621704102}}}
# [05/15/2022 19:22:41 INFO 139914211612480] #quality_metric: host=algo-1, epoch=8, train binary_classification_cross_entropy_objective <loss>=0.40450230407714843
# [05/15/2022 19:22:41 INFO 139914211612480] #early_stopping_criteria_metric: host=algo-1, epoch=8, criteria=binary_classification_cross_entropy_objective, value=0.35743036079406737
# [05/15/2022 19:22:41 INFO 139914211612480] Saving model for epoch: 8
# [05/15/2022 19:22:41 INFO 139914211612480] Saved checkpoint to "/tmp/tmph7g_tg4y/mx-mod-0000.params"
# [05/15/2022 19:22:41 INFO 139914211612480] Early stop condition met. Stopping training.
# [05/15/2022 19:22:41 INFO 139914211612480] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1652642561.3253858, "EndTime": 1652642561.7459202, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 10350.0, "count": 1, "min": 10350, "max": 10350}, "Total Batches Seen": {"sum": 111.0, "count": 1, "min": 111, "max": 111}, "Max Records Seen Between Resets": {"sum": 1025.0, "count": 1, "min": 1025, "max": 1025}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Number of Records Since Last Reset": {"sum": 1025.0, "count": 1, "min": 1025, "max": 1025}, "Number of Batches Since Last Reset": {"sum": 11.0, "count": 1, "min": 11, "max": 11}}}
# [05/15/2022 19:22:41 INFO 139914211612480] #throughput_metric: host=algo-1, train throughput=2436.4744480167483 records/second
# [05/15/2022 19:22:41 WARNING 139914211612480] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [05/15/2022 19:22:41 WARNING 139914211612480] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2022-05-15 19:22:41.747] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 22, "duration": 0, "num_examples": 1, "num_bytes": 9600}
# [2022-05-15 19:22:41.889] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 25, "duration": 139, "num_examples": 11, "num_bytes": 98400}
# [2022-05-15 19:22:41.948] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 27, "duration": 43, "num_examples": 11, "num_bytes": 98400}
# [05/15/2022 19:22:41 INFO 139914211612480] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.3524843727670065)
# [05/15/2022 19:22:41 INFO 139914211612480] #train_score (algo-1) : ('binary_classification_accuracy', 0.8575609756097561)
# [05/15/2022 19:22:41 INFO 139914211612480] #train_score (algo-1) : ('binary_f_1.000', 0.8601532567049809)
# [05/15/2022 19:22:41 INFO 139914211612480] #train_score (algo-1) : ('precision', 0.8667953667953668)
# [05/15/2022 19:22:41 INFO 139914211612480] #train_score (algo-1) : ('recall', 0.8536121673003803)
# [05/15/2022 19:22:41 INFO 139914211612480] #train_score (algo-1) : ('roc_auc_score', 0.9243620320488887)
# [05/15/2022 19:22:41 INFO 139914211612480] #train_score (algo-1) : ('binary_balanced_accuracy', 0.5)
# [05/15/2022 19:22:41 INFO 139914211612480] #train_score (algo-1) : ('binary_log_loss', 0.5946667597073777)
# [05/15/2022 19:22:41 INFO 139914211612480] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.3524843727670065
# [05/15/2022 19:22:41 INFO 139914211612480] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.8575609756097561
# [05/15/2022 19:22:41 INFO 139914211612480] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.8601532567049809
# [05/15/2022 19:22:41 INFO 139914211612480] #quality_metric: host=algo-1, train precision <score>=0.8667953667953668
# [05/15/2022 19:22:41 INFO 139914211612480] #quality_metric: host=algo-1, train recall <score>=0.8536121673003803
# [05/15/2022 19:22:41 INFO 139914211612480] #quality_metric: host=algo-1, train roc_auc_score <score>=0.9243620320488887
# [05/15/2022 19:22:41 INFO 139914211612480] #quality_metric: host=algo-1, train binary_balanced_accuracy <score>=0.5
# [05/15/2022 19:22:41 INFO 139914211612480] #quality_metric: host=algo-1, train binary_log_loss <score>=0.5946667597073777
# [05/15/2022 19:22:41 INFO 139914211612480] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [05/15/2022 19:22:41 INFO 139914211612480] Saved checkpoint to "/tmp/tmpnzsfls4q/mx-mod-0000.params"
# [05/15/2022 19:22:41 INFO 139914211612480] Test data is not provided.
# #metrics {"StartTime": 1652642556.9884386, "EndTime": 1652642561.9642336, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 229.49528694152832, "count": 1, "min": 229.49528694152832, "max": 229.49528694152832}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 7.001161575317383, "count": 9, "min": 0.2543926239013672, "max": 1.6303062438964844}, "update.time": {"sum": 4486.446142196655, "count": 9, "min": 416.4419174194336, "max": 660.5625152587891}, "finalize.time": {"sum": 211.6396427154541, "count": 1, "min": 211.6396427154541, "max": 211.6396427154541}, "setuptime": {"sum": 34.32011604309082, "count": 1, "min": 34.32011604309082, "max": 34.32011604309082}, "totaltime": {"sum": 5235.532522201538, "count": 1, "min": 5235.532522201538, "max": 5235.532522201538}}}
#
# 2022-05-15 19:23:05 Completed - Training job completed
# Training seconds: 113
# Billable seconds: 113

# %% [markdown]
# ## Hosting for the model

# %%
heartdisease_predictor = linear.deploy(initial_instance_count=1,
                                 instance_type='ml.m4.xlarge')
# Out:
# ---------!

# %% [markdown]
# ## Validate the model for use
# Finally, we can now validate the model for use.  We can pass HTTP POST requests to the endpoint to get back predictions.  To make this easier, we'll again use the Amazon SageMaker Python SDK and specify how to serialize requests and deserialize responses that are specific to the algorithm.

# %%
from sagemaker.predictor import csv_serializer, json_deserializer
heartdisease_predictor.serializer = csv_serializer
heartdisease_predictor.deserializer = json_deserializer

# %%
print('Endpoint name: {}'.format(heartdisease_predictor.endpoint))
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Endpoint name: linear-learner-2022-05-15-19-36-25-040

# %% [markdown]
# # Testing (Model)

# %%
vectors[5][0:13]
# Out:
# array([ 58.,   0.,   0., 100., 248.,   0.,   0., 122.,   0.,   1.,   1.,
#          0.,   2.], dtype=float32)

# %%
result = heartdisease_predictor.predict(vectors[5][0:13])
print(result)
# Out:
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# {'predictions': [{'score': 0.7061784267425537, 'predicted_label': 1}]}

# %%
import sagemaker

sagemaker.Session().delete_endpoint(heartdisease_predictor.endpoint)
